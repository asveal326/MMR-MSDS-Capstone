# %% [markdown]
# # Notebook 05: Forecasting and Scenarios (2030)
#
# Project country- or global-level maternal mortality under **alternative futures**. This notebook provides a **structure** for:
#
# - **Baseline**: extrapolation of predictors with historical trends (or holding recent levels fixed).
# - **Climate stress**: adverse changes to environmental exposures (e.g., higher PM2.5, more extreme heat days) relative to baseline.
#
# Quantify differences at **2030** (or your chosen horizon) and relate findings to SDG 3.1 where appropriate.

# %% [markdown]
# ## Workflow outline

# %% [markdown]
# 1. Train/finalize model on full sample (or through last observed year).
# 2. Construct latest cross-section per country.
# 3. Duplicate rows for each future year; adjust predictors per scenario.
# 4. Predict `log_mmr`, back-transform with `expm1`, aggregate/visualize.

# %% [markdown]
# ## Implementation (placeholder)

# %%
import pandas as pd
import numpy as np

# Load cleaned panel and fitted model from upstream notebooks
DATA_PATH = "../data/processed/country_year_modeling_panel_cleaned.csv"
df = pd.read_csv(DATA_PATH)

# TODO: retrain final model on full history or load persisted model
# TODO: build `latest` country snapshot and future-year rows through 2030

HORIZON_YEAR = 2030
future_years = list(range(df["year"].max() + 1, HORIZON_YEAR + 1))

# Placeholder DataFrames for scenario outputs
baseline_projection = None   # assign: country-year predictions under baseline assumptions
climate_stress_projection = None  # assign: same structure, stressed climate features

# Example scenario knobs (document assumptions in Markdown above)
# baseline: trend-project or carry-forward predictors
# climate_stress: e.g., pm25 *= 1.15; heat_index35_days *= 1.20

print("Future years to project:", future_years)
print("Populate baseline_projection and climate_stress_projection after fitting your model.")
